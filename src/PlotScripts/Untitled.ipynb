# %%
using Plots

epochs = 1:10
y0 = [0.8859, 0.89030, 0.8960, 0.8960, 0.8960, 0.8960, 0.8960, 0.8960, 0.8960, 0.8960]
y1 = [0.89013, 0.89023, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975]
y2 = [0.89013, 0.890, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975]
y3 = [0.9013, 0.9102, 0.9102, 0.9102, 0.9102, 0.9102, 0.9102, 0.9102, 0.9102, 0.9102]

p0 = plot(epochs, y0, title = "Training Set Size: 500", xlabel = "Epoch", ylabel = "Accuracy")
p1 = plot(epochs, y2, title = "Training Set Size: 1000", xlabel = "Epoch", ylabel = "Accuracy")
p2 = plot(epochs, y1, title = "Training Set Size: 2500", xlabel = "Epoch", ylabel = "Accuracy")
p3 = plot(epochs, y3, title = "Training Set Size: 10000", xlabel = "Epoch", ylabel = "Accuracy")
plot(p0, p1, p2, p3, layout = (2, 2), legend = false)
